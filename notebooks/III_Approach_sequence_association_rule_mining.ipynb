# %% [markdown]
# # Third approach Frequency-based Encoding

# %% [markdown]
# Finding frequent sequences and Association Rule Mining for Sequential Patterns

# %%
import pandas as pd
import pm4py
import logview
from sequential.seq2pat import Seq2Pat
from efficient_apriori import apriori

# %% [markdown]
# Filtered log includes only:
# - Start activities such as Create Purchase Order Item, Create Purchase Requisition Item, SRM Created, Vendor creates debit memo
# - End activities Clear Invoice, Delete Purchase Order Item
# - Only cases between 01.01.2018 and 31.12.2018

# %%
log2019_filtered = pm4py.read_xes(r"")
# Out:
# parsing log, completed traces ::   0%|          | 0/169380 [00:00<?, ?it/s]

# %%
log19df_filtered= pm4py.convert_to_dataframe(log2019_filtered)
log19df_filtered = log19df_filtered.sort_values(['case:concept:name', 'time:timestamp'], ignore_index=True)
log2019_filtered = pm4py.format_dataframe(log19df_filtered, case_id='case:concept:name', activity_key='concept:name', timestamp_key='time:timestamp')

# %%
from logview.utils import LogViewBuilder

log_view_filtered = LogViewBuilder.build_log_view(log2019_filtered)

# %%
from logview.predicate import *

query_pb = Query('Remove Payment Block', [EqToConstant('concept:name', 'Remove Payment Block')])
result_set_query_pb, complement_pb = log_view_filtered.evaluate_query('rs_Remove payment block', log2019_filtered, query_pb)

# %%
unique_events = sorted(log2019_filtered['concept:name'].unique())

# %%
result_set_query_pb_sorted = result_set_query_pb.sort_values(by=['case:concept:name', 'time:timestamp'])
complement_pb_sorted = complement_pb.sort_values(by=['case:concept:name', 'time:timestamp'])

# %%
def prepare_traces_as_sequences(df):
    sequences = df.groupby('case:concept:name')['concept:name'].apply(list).tolist()
    return sequences

# %%
sequences_with_remove = prepare_traces_as_sequences(result_set_query_pb_sorted)
sequences_without_remove = prepare_traces_as_sequences(complement_pb_sorted)

# %%
seq2pat_with = Seq2Pat(sequences_with_remove)
sequential_patterns_with_remove = seq2pat_with.get_patterns(min_frequency=2)

# %%
seq2pat_without = Seq2Pat(sequences_without_remove)
sequential_patterns_without_remove = seq2pat_without.get_patterns(min_frequency=2)

# %% [markdown]
# Comparisson

# %%
patterns_with_remove = {tuple(p[:-1]) for p in sequential_patterns_with_remove}
patterns_without_remove = {tuple(p[:-1]) for p in sequential_patterns_without_remove}

unique_to_with_remove = patterns_with_remove - patterns_without_remove
unique_to_without_remove = patterns_without_remove - patterns_with_remove

unique_to_with_remove_list = list(unique_to_with_remove)
unique_to_without_remove_list = list(unique_to_without_remove)

print("Unique Patterns in With-Remove Dataset:")
for i, pattern in enumerate(unique_to_with_remove_list[:5]): 
    print(f"Pattern: {pattern}")

print("\nUnique Patterns in Without-Remove Dataset:")
for i, pattern in enumerate(unique_to_without_remove_list[:5]): 
    print(f"Pattern: {pattern}")
# Out:
# Unique Patterns in With-Remove Dataset:
# Pattern: ('Change Quantity', 'Remove Payment Block', 'Vendor creates invoice', 'Clear Invoice', 'Record Invoice Receipt', 'Remove Payment Block', 'Clear Invoice')
# Pattern: ('Create Purchase Requisition Item', 'Create Purchase Order Item', 'Record Invoice Receipt', 'Record Goods Receipt', 'Cancel Subsequent Invoice')
# Pattern: ('Vendor creates debit memo', 'Vendor creates invoice', 'Record Goods Receipt', 'Cancel Invoice Receipt', 'Record Invoice Receipt', 'Record Invoice Receipt', 'Remove Payment Block')
# Pattern: ('Change Quantity', 'Vendor creates invoice', 'Vendor creates invoice', 'Record Invoice Receipt', 'Record Goods Receipt', 'Remove Payment Block', 'Record Invoice Receipt')
# Pattern: ('Receive Order Confirmation', 'Vendor creates invoice', 'Record Invoice Receipt', 'Vendor creates debit memo', 'Cancel Subsequent Invoice', 'Remove Payment Block', 'Clear Invoice', 'Clear Invoice')
#
# Unique Patterns in Without-Remove Dataset:
# Pattern: ('Clear Invoice', 'SRM: Complete', 'SRM: Awaiting Approval', 'SRM: In Transfer to Execution Syst.', 'SRM: Ordered', 'SRM: Deleted', 'Change Price')
# Pattern: ('SRM: Change was Transmitted', 'SRM: Created', 'SRM: Awaiting Approval', 'SRM: Document Completed', 'Record Goods Receipt')
# Pattern: ('Block Purchase Order Item', 'Change Quantity', 'Change Quantity', 'Record Goods Receipt', 'Vendor creates invoice', 'Record Invoice Receipt')
# Pattern: ('Create Purchase Order Item', 'Vendor creates debit memo', 'Change Quantity', 'Change Delivery Indicator', 'Record Invoice Receipt', 'Record Invoice Receipt')
# Pattern: ('Change Quantity', 'Change Price', 'Record Goods Receipt', 'Change Quantity', 'Record Goods Receipt', 'Clear Invoice')

# %% [markdown]
# Including support values

# %%
patterns_with_remove_1 = {tuple(p[:len(p)-1]): p[-1] for p in sequential_patterns_with_remove}
patterns_without_remove_1 = {tuple(p[:len(p)-1]): p[-1] for p in sequential_patterns_without_remove}

common_patterns_1 = {k: (patterns_with_remove_1[k], patterns_without_remove_1[k]) for k in patterns_with_remove_1 if k in patterns_without_remove_1}

unique_to_with_remove_1 = {k: patterns_with_remove_1[k] for k in patterns_with_remove_1 if k not in patterns_without_remove_1}
unique_to_without_remove_1 = {k: patterns_without_remove_1[k] for k in patterns_without_remove_1 if k not in patterns_with_remove_1}

print("Common Patterns with Support in Both Datasets:")
for i, (pattern, (support_with, support_without)) in enumerate(common_patterns_1.items()):
    if i < 5: 
        print(f"Pattern: {pattern}, Support in With-Remove: {support_with}, Support in Without-Remove: {support_without}")

print("\nUnique Patterns in With-Remove Dataset:")
for i, (pattern, support) in enumerate(unique_to_with_remove_1.items()):
    if i < 5:  
        print(f"Pattern: {pattern}, Support: {support}")

print("\nUnique Patterns in Without-Remove Dataset:")
for i, (pattern_without, support_without) in enumerate(unique_to_without_remove_1.items()):
    if i < 5: 
        print(f"Pattern: {pattern_without}, Support: {support_without}")
# Out:
# Common Patterns with Support in Both Datasets:
# Pattern: ('Record Invoice Receipt', 'Clear Invoice'), Support in With-Remove: 43292, Support in Without-Remove: 117793
# Pattern: ('Create Purchase Order Item', 'Vendor creates invoice'), Support in With-Remove: 43269, Support in Without-Remove: 117032
# Pattern: ('Record Goods Receipt', 'Clear Invoice'), Support in With-Remove: 43212, Support in Without-Remove: 117595
# Pattern: ('Vendor creates invoice', 'Clear Invoice'), Support in With-Remove: 43205, Support in Without-Remove: 117559
# Pattern: ('Create Purchase Order Item', 'Record Goods Receipt'), Support in With-Remove: 43150, Support in Without-Remove: 117734
#
# Unique Patterns in With-Remove Dataset:
# Pattern: ('Remove Payment Block', 'Clear Invoice'), Support: 43346
# Pattern: ('Record Invoice Receipt', 'Remove Payment Block'), Support: 43299
# Pattern: ('Record Invoice Receipt', 'Remove Payment Block', 'Clear Invoice'), Support: 43284
# Pattern: ('Vendor creates invoice', 'Remove Payment Block'), Support: 43153
# Pattern: ('Vendor creates invoice', 'Remove Payment Block', 'Clear Invoice'), Support: 43039
#
# Unique Patterns in Without-Remove Dataset:
# Pattern: ('Create Purchase Requisition Item', 'Create Purchase Order Item', 'Delete Purchase Order Item'), Support: 1456
# Pattern: ('Create Purchase Requisition Item', 'Delete Purchase Order Item'), Support: 1456
# Pattern: ('SRM: Awaiting Approval', 'Record Invoice Receipt', 'Clear Invoice'), Support: 619
# Pattern: ('SRM: Awaiting Approval', 'SRM: Document Completed', 'Record Invoice Receipt', 'Clear Invoice'), Support: 619
# Pattern: ('SRM: Awaiting Approval', 'SRM: Document Completed', 'SRM: In Transfer to Execution Syst.', 'Record Invoice Receipt', 'Clear Invoice'), Support: 619

# %% [markdown]
# Association Rule Mining for Sequential Patterns

# %%
transactions_with = [list(pattern) for pattern in patterns_with_remove_1.keys()]  # For 'With Remove Payment Block'
transactions_without = [list(pattern) for pattern in patterns_without_remove_1.keys()]  # For 'Without Remove Payment Block'

print("Association Rules for Transactions WITH 'Remove Payment Block")
itemsets_with, rules_with = apriori(transactions_with, min_support=0.01, min_confidence=0.7)

print("\nFrequent Itemsets (With):")
for itemset, support in itemsets_with.items():
    print(f"{itemset}: {support}")

print("\nAssociation Rules (With):")
for rule in rules_with:
    print(rule)

with open('rules_with_remove_payment_block.txt', 'w') as f:
    f.write("Frequent Itemsets (With):\n")
    for itemset, support in itemsets_with.items():
        f.write(f"{itemset}: {support}\n")
    f.write("\nAssociation Rules (With):\n")
    for rule in rules_with:
        f.write(str(rule) + '\n')


print("Association Rules for Transactions WITHOUT 'Remove Payment Block")
itemsets_without, rules_without = apriori(transactions_without, min_support=0.01, min_confidence=0.7)

print("\nFrequent Itemsets (Without):")
for itemset, support in itemsets_without.items():
    print(f"{itemset}: {support}")

print("\nAssociation Rules (Without):")
for rule in rules_without:
    print(rule)

with open('rules_without_remove_payment_block.txt', 'w') as f:
    f.write("Frequent Itemsets (Without):\n")
    for itemset, support in itemsets_without.items():
        f.write(f"{itemset}: {support}\n")
    f.write("\nAssociation Rules (Without):\n")
    for rule in rules_without:
        f.write(str(rule) + '\n')
# Out:
# Association Rules for Transactions WITH 'Remove Payment Block
#
# Frequent Itemsets (With):
# 1: {('Remove Payment Block',): 141259, ('Clear Invoice',): 142871, ('Record Invoice Receipt',): 192614, ('Create Purchase Order Item',): 74242, ('Vendor creates invoice',): 171422, ('Record Goods Receipt',): 169955, ('Receive Order Confirmation',): 13195, ('Change Quantity',): 75325, ('Create Purchase Requisition Item',): 9095, ('Change Price',): 46159, ('Vendor creates debit memo',): 83438, ('Cancel Invoice Receipt',): 78356, ('Change Delivery Indicator',): 32431, ('Change Approval for Purchase Order',): 16680, ('Cancel Subsequent Invoice',): 12944, ('Record Service Entry Sheet',): 14352, ('Cancel Goods Receipt',): 13508, ('Release Purchase Order',): 12219, ('Reactivate Purchase Order Item',): 7273, ('SRM: Awaiting Approval',): 8403, ('SRM: Change was Transmitted',): 8913, ('SRM: Document Completed',): 9702, ('SRM: In Transfer to Execution Syst.',): 11153, ('SRM: Ordered',): 10948, ('SRM: Complete',): 7031, ('SRM: Created',): 5288, ('Delete Purchase Order Item',): 2839, ('Block Purchase Order Item',): 6181, ('Record Subsequent Invoice',): 4878}
# 2: {('Block Purchase Order Item', 'Change Quantity'): 3454, ('Block Purchase Order Item', 'Reactivate Purchase Order Item'): 3595, ('Block Purchase Order Item', 'Record Goods Receipt'): 3138, ('Block Purchase Order Item', 'Record Invoice Receipt'): 3715, ('Block Purchase Order Item', 'Vendor creates invoice'): 2948, ('Cancel Goods Receipt', 'Change Quantity'): 3419, ('Cancel Goods Receipt', 'Clear Invoice'): 4430, ('Cancel Goods Receipt', 'Create Purchase Order Item'): 4237, ('Cancel Goods Receipt', 'Record Goods Receipt'): 10163, ('Cancel Goods Receipt', 'Record Invoice Receipt'): 7400, ('Cancel Goods Receipt', 'Remove Payment Block'): 5988, ('Cancel Goods Receipt', 'Vendor creates invoice'): 7264, ('Cancel Invoice Receipt', 'Change Delivery Indicator'): 6056, ('Cancel Invoice Receipt', 'Change Price'): 8035, ('Cancel Invoice Receipt', 'Change Quantity'): 12344, ('Cancel Invoice Receipt', 'Clear Invoice'): 52419, ('Cancel Invoice Receipt', 'Create Purchase Order Item'): 15383, ('Cancel Invoice Receipt', 'Record Goods Receipt'): 41021, ('Cancel Invoice Receipt', 'Record Invoice Receipt'): 62063, ('Cancel Invoice Receipt', 'Remove Payment Block'): 44033, ('Cancel Invoice Receipt', 'Vendor creates debit memo'): 39659, ('Cancel Invoice Receipt', 'Vendor creates invoice'): 44138, ('Cancel Subsequent Invoice', 'Clear Invoice'): 9041, ('Cancel Subsequent Invoice', 'Create Purchase Order Item'): 2910, ('Cancel Subsequent Invoice', 'Record Goods Receipt'): 5087, ('Cancel Subsequent Invoice', 'Record Invoice Receipt'): 7784, ('Cancel Subsequent Invoice', 'Remove Payment Block'): 7427, ('Cancel Subsequent Invoice', 'Vendor creates debit memo'): 7491, ('Cancel Subsequent Invoice', 'Vendor creates invoice'): 6746, ('Change Approval for Purchase Order', 'Change Price'): 7759, ('Change Approval for Purchase Order', 'Change Quantity'): 6931, ('Change Approval for Purchase Order', 'Clear Invoice'): 3743, ('Change Approval for Purchase Order', 'Create Purchase Order Item'): 3720, ('Change Approval for Purchase Order', 'Record Goods Receipt'): 7993, ('Change Approval for Purchase Order', 'Record Invoice Receipt'): 7580, ('Change Approval for Purchase Order', 'Release Purchase Order'): 9807, ('Change Approval for Purchase Order', 'Remove Payment Block'): 6207, ('Change Approval for Purchase Order', 'Vendor creates invoice'): 7349, ('Change Delivery Indicator', 'Change Quantity'): 13268, ('Change Delivery Indicator', 'Clear Invoice'): 14709, ('Change Delivery Indicator', 'Create Purchase Order Item'): 8875, ('Change Delivery Indicator', 'Record Goods Receipt'): 21545, ('Change Delivery Indicator', 'Record Invoice Receipt'): 21084, ('Change Delivery Indicator', 'Remove Payment Block'): 15458, ('Change Delivery Indicator', 'Vendor creates debit memo'): 6974, ('Change Delivery Indicator', 'Vendor creates invoice'): 19667, ('Change Price', 'Change Quantity'): 14171, ('Change Price', 'Clear Invoice'): 18610, ('Change Price', 'Create Purchase Order Item'): 12590, ('Change Price', 'Record Goods Receipt'): 26014, ('Change Price', 'Record Invoice Receipt'): 27603, ('Change Price', 'Release Purchase Order'): 6640, ('Change Price', 'Remove Payment Block'): 21916, ('Change Price', 'Vendor creates debit memo'): 9177, ('Change Price', 'Vendor creates invoice'): 24307, ('Change Quantity', 'Clear Invoice'): 30602, ('Change Quantity', 'Create Purchase Order Item'): 20175, ('Change Quantity', 'Reactivate Purchase Order Item'): 3639, ('Change Quantity', 'Record Goods Receipt'): 49439, ('Change Quantity', 'Record Invoice Receipt'): 48561, ('Change Quantity', 'Release Purchase Order'): 5153, ('Change Quantity', 'Remove Payment Block'): 34553, ('Change Quantity', 'Vendor creates debit memo'): 14526, ('Change Quantity', 'Vendor creates invoice'): 46771, ('Clear Invoice', 'Create Purchase Order Item'): 29946, ('Clear Invoice', 'Create Purchase Requisition Item'): 3868, ('Clear Invoice', 'Receive Order Confirmation'): 5851, ('Clear Invoice', 'Record Goods Receipt'): 8329 ...
# 3: {('Cancel Goods Receipt', 'Clear Invoice', 'Record Goods Receipt'): 3089, ('Cancel Goods Receipt', 'Create Purchase Order Item', 'Record Goods Receipt'): 3107, ('Cancel Goods Receipt', 'Record Goods Receipt', 'Record Invoice Receipt'): 5512, ('Cancel Goods Receipt', 'Record Goods Receipt', 'Remove Payment Block'): 4350, ('Cancel Goods Receipt', 'Record Goods Receipt', 'Vendor creates invoice'): 5441, ('Cancel Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block'): 3466, ('Cancel Goods Receipt', 'Record Invoice Receipt', 'Vendor creates invoice'): 4038, ('Cancel Goods Receipt', 'Remove Payment Block', 'Vendor creates invoice'): 3227, ('Cancel Invoice Receipt', 'Change Delivery Indicator', 'Clear Invoice'): 3379, ('Cancel Invoice Receipt', 'Change Delivery Indicator', 'Record Goods Receipt'): 3087, ('Cancel Invoice Receipt', 'Change Delivery Indicator', 'Record Invoice Receipt'): 3888, ('Cancel Invoice Receipt', 'Change Delivery Indicator', 'Vendor creates debit memo'): 3129, ('Cancel Invoice Receipt', 'Change Delivery Indicator', 'Vendor creates invoice'): 3110, ('Cancel Invoice Receipt', 'Change Price', 'Clear Invoice'): 4572, ('Cancel Invoice Receipt', 'Change Price', 'Record Goods Receipt'): 3941, ('Cancel Invoice Receipt', 'Change Price', 'Record Invoice Receipt'): 6156, ('Cancel Invoice Receipt', 'Change Price', 'Remove Payment Block'): 4343, ('Cancel Invoice Receipt', 'Change Price', 'Vendor creates debit memo'): 3906, ('Cancel Invoice Receipt', 'Change Price', 'Vendor creates invoice'): 4215, ('Cancel Invoice Receipt', 'Change Quantity', 'Clear Invoice'): 6572, ('Cancel Invoice Receipt', 'Change Quantity', 'Record Goods Receipt'): 6599, ('Cancel Invoice Receipt', 'Change Quantity', 'Record Invoice Receipt'): 8747, ('Cancel Invoice Receipt', 'Change Quantity', 'Remove Payment Block'): 5588, ('Cancel Invoice Receipt', 'Change Quantity', 'Vendor creates debit memo'): 6143, ('Cancel Invoice Receipt', 'Change Quantity', 'Vendor creates invoice'): 6541, ('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item'): 7945, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt'): 25606, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Invoice Receipt'): 42078, ('Cancel Invoice Receipt', 'Clear Invoice', 'Remove Payment Block'): 30525, ('Cancel Invoice Receipt', 'Clear Invoice', 'Vendor creates debit memo'): 25059, ('Cancel Invoice Receipt', 'Clear Invoice', 'Vendor creates invoice'): 27790, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Goods Receipt'): 9250, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Invoice Receipt'): 11456, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Remove Payment Block'): 8024, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Vendor creates debit memo'): 9128, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Vendor creates invoice'): 9963, ('Cancel Invoice Receipt', 'Record Goods Receipt', 'Record Invoice Receipt'): 32237, ('Cancel Invoice Receipt', 'Record Goods Receipt', 'Remove Payment Block'): 21688, ('Cancel Invoice Receipt', 'Record Goods Receipt', 'Vendor creates debit memo'): 21204, ('Cancel Invoice Receipt', 'Record Goods Receipt', 'Vendor creates invoice'): 24832, ('Cancel Invoice Receipt', 'Record Invoice Receipt', 'Remove Payment Block'): 34944, ('Cancel Invoice Receipt', 'Record Invoice Receipt', 'Vendor creates debit memo'): 30833, ('Cancel Invoice Receipt', 'Record Invoice Receipt', 'Vendor creates invoice'): 34744, ('Cancel Invoice Receipt', 'Remove Payment Block', 'Vendor creates debit memo'): 21284, ('Cancel Invoice Receipt', 'Remove Payment Block', 'Vendor creates invoice'): 23582, ('Cancel Invoice Receipt', 'Vendor creates debit memo', 'Vendor creates invoice'): 24012, ('Cancel Subsequent Invoice', 'Clear Invoice', 'Record Goods Receipt'): 3174, ('Cancel Subsequent Invoice', 'Clear Invoice', 'Record Invoice Receipt'): 5318, ('Cancel Subsequent Invoice', 'Clear Invoice', 'Remove ...
# 4: {('Cancel Goods Receipt', 'Record Goods Receipt', 'Record Invoice Receipt', 'Vendor creates invoice'): 2993, ('Cancel Invoice Receipt', 'Change Price', 'Clear Invoice', 'Record Invoice Receipt'): 3507, ('Cancel Invoice Receipt', 'Change Price', 'Record Goods Receipt', 'Record Invoice Receipt'): 2994, ('Cancel Invoice Receipt', 'Change Price', 'Record Invoice Receipt', 'Remove Payment Block'): 3325, ('Cancel Invoice Receipt', 'Change Price', 'Record Invoice Receipt', 'Vendor creates debit memo'): 2951, ('Cancel Invoice Receipt', 'Change Price', 'Record Invoice Receipt', 'Vendor creates invoice'): 3194, ('Cancel Invoice Receipt', 'Change Quantity', 'Clear Invoice', 'Record Goods Receipt'): 3394, ('Cancel Invoice Receipt', 'Change Quantity', 'Clear Invoice', 'Record Invoice Receipt'): 4705, ('Cancel Invoice Receipt', 'Change Quantity', 'Clear Invoice', 'Remove Payment Block'): 3035, ('Cancel Invoice Receipt', 'Change Quantity', 'Clear Invoice', 'Vendor creates debit memo'): 3069, ('Cancel Invoice Receipt', 'Change Quantity', 'Clear Invoice', 'Vendor creates invoice'): 3232, ('Cancel Invoice Receipt', 'Change Quantity', 'Record Goods Receipt', 'Record Invoice Receipt'): 4626, ('Cancel Invoice Receipt', 'Change Quantity', 'Record Goods Receipt', 'Remove Payment Block'): 2902, ('Cancel Invoice Receipt', 'Change Quantity', 'Record Goods Receipt', 'Vendor creates debit memo'): 3234, ('Cancel Invoice Receipt', 'Change Quantity', 'Record Goods Receipt', 'Vendor creates invoice'): 3534, ('Cancel Invoice Receipt', 'Change Quantity', 'Record Invoice Receipt', 'Remove Payment Block'): 3949, ('Cancel Invoice Receipt', 'Change Quantity', 'Record Invoice Receipt', 'Vendor creates debit memo'): 4317, ('Cancel Invoice Receipt', 'Change Quantity', 'Record Invoice Receipt', 'Vendor creates invoice'): 4611, ('Cancel Invoice Receipt', 'Change Quantity', 'Remove Payment Block', 'Vendor creates invoice'): 2835, ('Cancel Invoice Receipt', 'Change Quantity', 'Vendor creates debit memo', 'Vendor creates invoice'): 3340, ('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item', 'Record Goods Receipt'): 4678, ('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item', 'Record Invoice Receipt'): 5973, ('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item', 'Remove Payment Block'): 4330, ('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item', 'Vendor creates debit memo'): 4664, ('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item', 'Vendor creates invoice'): 5084, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Record Invoice Receipt'): 20386, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Remove Payment Block'): 13989, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Vendor creates debit memo'): 12571, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Vendor creates invoice'): 14876, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Invoice Receipt', 'Remove Payment Block'): 24441, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Invoice Receipt', 'Vendor creates debit memo'): 19658, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Invoice Receipt', 'Vendor creates invoice'): 22112, ('Cancel Invoice Receipt', 'Clear Invoice', 'Remove Payment Block', 'Vendor creates debit memo'): 13929, ('Cancel Invoice Receipt', 'Clear Invoice', 'Remove Payment Block', 'Vendor creates invoice'): 15256, ('Cancel Invoice Receipt', 'Clear Invoice', 'Vendor creates debit memo', 'Vendor creates invoice'): 14587, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Goods Receipt', 'Record Invoice Receipt'): 6983, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Goods Receipt', 'Remove Payment Block'): 4746, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Goods Receipt', 'Vendor creates debit memo'): 5499, ('Cancel Invoice Receipt', 'Create Purchase Order Item', ...
# 5: {('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item', 'Record Goods Receipt', 'Record Invoice Receipt'): 3580, ('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item', 'Record Goods Receipt', 'Vendor creates invoice'): 3032, ('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item', 'Record Invoice Receipt', 'Remove Payment Block'): 3254, ('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item', 'Record Invoice Receipt', 'Vendor creates debit memo'): 3516, ('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item', 'Record Invoice Receipt', 'Vendor creates invoice'): 3846, ('Cancel Invoice Receipt', 'Clear Invoice', 'Create Purchase Order Item', 'Vendor creates debit memo', 'Vendor creates invoice'): 2998, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block'): 11056, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Record Invoice Receipt', 'Vendor creates debit memo'): 9849, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Record Invoice Receipt', 'Vendor creates invoice'): 11791, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Remove Payment Block', 'Vendor creates debit memo'): 6709, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Remove Payment Block', 'Vendor creates invoice'): 7825, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Vendor creates debit memo', 'Vendor creates invoice'): 7619, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates debit memo'): 10865, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates invoice'): 12048, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Invoice Receipt', 'Vendor creates debit memo', 'Vendor creates invoice'): 11464, ('Cancel Invoice Receipt', 'Clear Invoice', 'Remove Payment Block', 'Vendor creates debit memo', 'Vendor creates invoice'): 7824, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block'): 3619, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Goods Receipt', 'Record Invoice Receipt', 'Vendor creates debit memo'): 4153, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Goods Receipt', 'Record Invoice Receipt', 'Vendor creates invoice'): 4612, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Goods Receipt', 'Remove Payment Block', 'Vendor creates invoice'): 3081, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Goods Receipt', 'Vendor creates debit memo', 'Vendor creates invoice'): 3611, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates debit memo'): 3528, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates invoice'): 3901, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Record Invoice Receipt', 'Vendor creates debit memo', 'Vendor creates invoice'): 4473, ('Cancel Invoice Receipt', 'Create Purchase Order Item', 'Remove Payment Block', 'Vendor creates debit memo', 'Vendor creates invoice'): 3034, ('Cancel Invoice Receipt', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates debit memo'): 8455, ('Cancel Invoice Receipt', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates invoice'): 9942, ('Cancel Invoice Receipt', 'Record Goods Receipt', 'Record Invoice Receipt', 'Vendor creates debit memo', 'Vendor creates invoice'): 10300, ('Cancel Invoice Receipt', 'Record Goods Receipt', 'Remove Payment Block', 'Vendor creates debit memo', 'Vendor creates invoice'): 6619, ('Cancel Invoice Receipt', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor cre ...
# 6: {('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates debit memo'): 5230, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates invoice'): 6149, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Record Invoice Receipt', 'Vendor creates debit memo', 'Vendor creates invoice'): 5960, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Remove Payment Block', 'Vendor creates debit memo', 'Vendor creates invoice'): 3930, ('Cancel Invoice Receipt', 'Clear Invoice', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates debit memo', 'Vendor creates invoice'): 6103, ('Cancel Invoice Receipt', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates debit memo', 'Vendor creates invoice'): 5121, ('Change Quantity', 'Clear Invoice', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates invoice'): 4178, ('Clear Invoice', 'Create Purchase Order Item', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates invoice'): 5274, ('Clear Invoice', 'Create Purchase Order Item', 'Record Goods Receipt', 'Record Invoice Receipt', 'Vendor creates debit memo', 'Vendor creates invoice'): 3062, ('Clear Invoice', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates debit memo', 'Vendor creates invoice'): 6225, ('Create Purchase Order Item', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates debit memo', 'Vendor creates invoice'): 3107}
# 7: {('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Record Invoice Receipt', 'Remove Payment Block', 'Vendor creates debit memo', 'Vendor creates invoice'): 3056}
#
# Association Rules (With):
# {Cancel Goods Receipt} -> {Record Goods Receipt} (conf: 0.752, supp: 0.037, lift: 1.232, conv: 1.572)
# {Cancel Invoice Receipt} -> {Record Invoice Receipt} (conf: 0.792, supp: 0.223, lift: 1.145, conv: 1.481)
# {Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.803, supp: 0.035, lift: 13.392, conv: 4.762)
# {Clear Invoice} -> {Record Invoice Receipt} (conf: 0.751, supp: 0.385, lift: 1.085, conv: 1.235)
# {Record Subsequent Invoice} -> {Clear Invoice} (conf: 0.704, supp: 0.012, lift: 1.371, conv: 1.643)
# {Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.708, supp: 0.432, lift: 1.023, conv: 1.055)
# {Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.733, supp: 0.372, lift: 1.059, conv: 1.153)
# {Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.736, supp: 0.221, lift: 1.064, conv: 1.167)
# {Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.709, supp: 0.437, lift: 1.024, conv: 1.058)
# {Cancel Goods Receipt, Create Purchase Order Item} -> {Record Goods Receipt} (conf: 0.733, supp: 0.011, lift: 1.201, conv: 1.460)
# {Cancel Goods Receipt, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.745, supp: 0.020, lift: 1.220, conv: 1.526)
# {Cancel Goods Receipt, Remove Payment Block} -> {Record Goods Receipt} (conf: 0.726, supp: 0.016, lift: 1.190, conv: 1.423)
# {Cancel Goods Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.749, supp: 0.020, lift: 1.227, conv: 1.551)
# {Cancel Invoice Receipt, Change Price} -> {Record Invoice Receipt} (conf: 0.766, supp: 0.022, lift: 1.107, conv: 1.317)
# {Cancel Invoice Receipt, Change Quantity} -> {Record Invoice Receipt} (conf: 0.709, supp: 0.031, lift: 1.024, conv: 1.057)
# {Cancel Invoice Receipt, Clear Invoice} -> {Record Invoice Receipt} (conf: 0.803, supp: 0.151, lift: 1.160, conv: 1.561)
# {Cancel Invoice Receipt, Create Purchase Order Item} -> {Record Invoice Receipt} (conf: 0.745, supp: 0.041, lift: 1.076, conv: 1.206)
# {Cancel Invoice Receipt, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.786, supp: 0.116, lift: 1.136, conv: 1.438)
# {Cancel Invoice Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.794, supp: 0.126, lift: 1.147, conv: 1.492)
# {Cancel Invoice Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.777, supp: 0.111, lift: 1.123, conv: 1.384)
# {Cancel Invoice Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.787, supp: 0.125, lift: 1.137, conv: 1.447)
# {Cancel Subsequent Invoice, Remove Payment Block} -> {Clear Invoice} (conf: 0.716, supp: 0.019, lift: 1.394, conv: 1.712)
# {Change Price, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.773, supp: 0.018, lift: 12.894, conv: 4.137)
# {Change Quantity, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.764, supp: 0.014, lift: 12.752, conv: 3.987)
# {Record Goods Receipt, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.759, supp: 0.014, lift: 12.662, conv: 3.898)
# {Record Invoice Receipt, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.751, supp: 0.013, lift: 12.534, conv: 3.778)
# {Release Purchase Order, Remove Payment Block} -> {Change Approval for Purchase Order} (conf: 0.762, supp: 0.012, lift: 12.716, conv: 3.951)
# {Release Purchase Order, Vendor creates invoice} -> {Change Approval for Purchase Order} (conf: 0.756, supp: 0.012, lift: 12.607, conv: 3.846)
# {Change Price, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.715, supp: 0.024, lift: 1.032, conv: 1.079)
# {Clear Invoice, Create Purchase Order Item} -> {Record Invoice Receipt} (conf: 0.702, supp: 0.076, lift: 1.015, conv: 1.034)
# {Clear Invoice, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.753, supp: 0.225, lift: 1.089, conv: 1.249)
# {Clear Invoice, Record Service Entry Sheet} -> {Record Invoice Receipt} (conf: 0.734, supp: 0.017, lift: 1.061, conv: 1.158)
# {Clear Invoice, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.751, supp: 0.222, lift: 1.084, conv: 1.234)
# {Clear Invoice, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.751, supp: 0.134, lift: 1.086, conv: 1.239)
# {Clear Invoice, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.754, supp: 0.232, lift: 1.089, conv: 1.250)
# {Receive Order Confirmation, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.706, supp: 0.022, lift: 1.021, conv: 1.048)
# {Receive Order Confirmation, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.707, supp: 0.017, lift: 1.021, conv: 1.050)
# {Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.736, supp: 0.224, lift: 1.064, conv: 1.167)
# {Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.742, supp: 0.124, lift: 1.072, conv: 1.193)
# {Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.721, supp: 0.287, lift: 1.042, conv: 1.104)
# {Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.744, supp: 0.117, lift: 1.075, conv: 1.203)
# {Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.742, supp: 0.231, lift: 1.072, conv: 1.194)
# {Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.740, supp: 0.140, lift: 1.070, conv: 1.186)
# {Cancel Goods Receipt, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.741, supp: 0.011, lift: 1.214, conv: 1.505)
# {Cancel Invoice Receipt, Change Price, Clear Invoice} -> {Record Invoice Receipt} (conf: 0.767, supp: 0.013, lift: 1.108, conv: 1.322)
# {Cancel Invoice Receipt, Change Price, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.760, supp: 0.011, lift: 1.098, conv: 1.282)
# {Cancel Invoice Receipt, Change Price, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.766, supp: 0.012, lift: 1.106, conv: 1.314)
# {Cancel Invoice Receipt, Change Price, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.756, supp: 0.011, lift: 1.092, conv: 1.260)
# {Cancel Invoice Receipt, Change Price, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.758, supp: 0.011, lift: 1.095, conv: 1.271)
# {Cancel Invoice Receipt, Change Quantity, Clear Invoice} -> {Record Invoice Receipt} (conf: 0.716, supp: 0.017, lift: 1.034, conv: 1.084)
# {Cancel Invoice Receipt, Change Quantity, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.701, supp: 0.017, lift: 1.013, conv: 1.030)
# {Cancel Invoice Receipt, Change Quantity, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.707, supp: 0.014, lift: 1.021, conv: 1.050)
# {Cancel Invoice Receipt, Change Quantity, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.703, supp: 0.016, lift: 1.015, conv: 1.036)
# {Cancel Invoice Receipt, Change Quantity, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.705, supp: 0.017, lift: 1.019, conv: 1.044)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item} -> {Record Invoice Receipt} (conf: 0.752, supp: 0.021, lift: 1.086, conv: 1.241)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.796, supp: 0.073, lift: 1.150, conv: 1.511)
# {Cancel Invoice Receipt, Clear Invoice, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.801, supp: 0.088, lift: 1.157, conv: 1.545)
# {Cancel Invoice Receipt, Clear Invoice, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.784, supp: 0.071, lift: 1.134, conv: 1.429)
# {Cancel Invoice Receipt, Clear Invoice, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.796, supp: 0.079, lift: 1.150, conv: 1.507)
# {Cancel Invoice Receipt, Create Purchase Order Item, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.755, supp: 0.025, lift: 1.091, conv: 1.256)
# {Cancel Invoice Receipt, Create Purchase Order Item, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.750, supp: 0.022, lift: 1.083, conv: 1.231)
# {Cancel Invoice Receipt, Create Purchase Order Item, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.746, supp: 0.024, lift: 1.078, conv: 1.211)
# {Cancel Invoice Receipt, Create Purchase Order Item, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.752, supp: 0.027, lift: 1.086, conv: 1.241)
# {Cancel Invoice Receipt, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.785, supp: 0.061, lift: 1.134, conv: 1.430)
# {Cancel Invoice Receipt, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.776, supp: 0.059, lift: 1.121, conv: 1.372)
# {Cancel Invoice Receipt, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.784, supp: 0.070, lift: 1.132, conv: 1.424)
# {Cancel Invoice Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.777, supp: 0.059, lift: 1.122, conv: 1.380)
# {Cancel Invoice Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.785, supp: 0.067, lift: 1.135, conv: 1.435)
# {Cancel Invoice Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.779, supp: 0.067, lift: 1.126, conv: 1.396)
# {Cancel Subsequent Invoice, Remove Payment Block, Vendor creates debit memo} -> {Clear Invoice} (conf: 0.714, supp: 0.011, lift: 1.390, conv: 1.700)
# {Change Price, Clear Invoice, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.718, supp: 0.013, lift: 1.037, conv: 1.090)
# {Change Price, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.711, supp: 0.012, lift: 1.027, conv: 1.064)
# {Change Price, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.724, supp: 0.012, lift: 1.046, conv: 1.115)
# {Change Price, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.715, supp: 0.013, lift: 1.033, conv: 1.080)
# {Change Quantity, Clear Invoice, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.700, supp: 0.049, lift: 1.012, conv: 1.027)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.714, supp: 0.050, lift: 1.032, conv: 1.078)
# {Clear Invoice, Create Purchase Order Item, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.703, supp: 0.042, lift: 1.016, conv: 1.036)
# {Clear Invoice, Create Purchase Order Item, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.718, supp: 0.028, lift: 1.038, conv: 1.094)
# {Clear Invoice, Create Purchase Order Item, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.712, supp: 0.051, lift: 1.029, conv: 1.069)
# {Clear Invoice, Record Goods Receipt, Record Service Entry Sheet} -> {Record Invoice Receipt} (conf: 0.718, supp: 0.010, lift: 1.037, conv: 1.091)
# {Clear Invoice, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.751, supp: 0.124, lift: 1.085, conv: 1.236)
# {Clear Invoice, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.759, supp: 0.070, lift: 1.097, conv: 1.278)
# {Clear Invoice, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.757, supp: 0.144, lift: 1.093, conv: 1.265)
# {Clear Invoice, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.745, supp: 0.074, lift: 1.077, conv: 1.210)
# {Clear Invoice, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.750, supp: 0.131, lift: 1.084, conv: 1.234)
# {Clear Invoice, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.753, supp: 0.081, lift: 1.089, conv: 1.249)
# {Create Purchase Order Item, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.712, supp: 0.058, lift: 1.028, conv: 1.068)
# {Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.712, supp: 0.034, lift: 1.028, conv: 1.068)
# {Create Purchase Order Item, Record Goods Receipt, Record Invoice Receipt} -> {Vendor creates invoice} (conf: 0.703, supp: 0.080, lift: 1.141, conv: 1.291)
# {Create Purchase Order Item, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.716, supp: 0.028, lift: 1.035, conv: 1.084)
# {Create Purchase Order Item, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.711, supp: 0.060, lift: 1.028, conv: 1.067)
# {Create Purchase Order Item, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.707, supp: 0.037, lift: 1.022, conv: 1.052)
# {Receive Order Confirmation, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.721, supp: 0.011, lift: 1.042, conv: 1.105)
# {Receive Order Confirmation, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.709, supp: 0.015, lift: 1.025, conv: 1.059)
# {Receive Order Confirmation, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.711, supp: 0.011, lift: 1.027, conv: 1.064)
# {Record Goods Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.748, supp: 0.062, lift: 1.081, conv: 1.223)
# {Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.746, supp: 0.148, lift: 1.078, conv: 1.211)
# {Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.743, supp: 0.081, lift: 1.073, conv: 1.197)
# {Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.745, supp: 0.072, lift: 1.077, conv: 1.209)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.765, supp: 0.013, lift: 1.106, conv: 1.312)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.752, supp: 0.012, lift: 1.086, conv: 1.239)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.754, supp: 0.013, lift: 1.089, conv: 1.251)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.756, supp: 0.014, lift: 1.093, conv: 1.265)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.790, supp: 0.040, lift: 1.142, conv: 1.469)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.783, supp: 0.035, lift: 1.132, conv: 1.422)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.793, supp: 0.042, lift: 1.145, conv: 1.485)
# {Cancel Invoice Receipt, Clear Invoice, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.780, supp: 0.039, lift: 1.127, conv: 1.400)
# {Cancel Invoice Receipt, Clear Invoice, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.790, supp: 0.043, lift: 1.141, conv: 1.464)
# {Cancel Invoice Receipt, Clear Invoice, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.786, supp: 0.041, lift: 1.136, conv: 1.438)
# {Cancel Invoice Receipt, Create Purchase Order Item, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.763, supp: 0.013, lift: 1.102, conv: 1.297)
# {Cancel Invoice Receipt, Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.755, supp: 0.015, lift: 1.091, conv: 1.258)
# {Cancel Invoice Receipt, Create Purchase Order Item, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.758, supp: 0.017, lift: 1.096, conv: 1.275)
# {Cancel Invoice Receipt, Create Purchase Order Item, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.749, supp: 0.013, lift: 1.083, conv: 1.228)
# {Cancel Invoice Receipt, Create Purchase Order Item, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.756, supp: 0.014, lift: 1.093, conv: 1.264)
# {Cancel Invoice Receipt, Create Purchase Order Item, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.752, supp: 0.016, lift: 1.087, conv: 1.243)
# {Cancel Invoice Receipt, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.775, supp: 0.030, lift: 1.120, conv: 1.371)
# {Cancel Invoice Receipt, Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.781, supp: 0.036, lift: 1.129, conv: 1.409)
# {Cancel Invoice Receipt, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.775, supp: 0.037, lift: 1.120, conv: 1.370)
# {Cancel Invoice Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.777, supp: 0.035, lift: 1.123, conv: 1.382)
# {Change Quantity, Clear Invoice, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.702, supp: 0.030, lift: 1.014, conv: 1.033)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.717, supp: 0.028, lift: 1.036, conv: 1.089)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.731, supp: 0.017, lift: 1.056, conv: 1.145)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.721, supp: 0.034, lift: 1.042, conv: 1.104)
# {Clear Invoice, Create Purchase Order Item, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.718, supp: 0.015, lift: 1.038, conv: 1.093)
# {Clear Invoice, Create Purchase Order Item, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.713, supp: 0.028, lift: 1.030, conv: 1.073)
# {Clear Invoice, Create Purchase Order Item, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.724, supp: 0.018, lift: 1.047, conv: 1.118)
# {Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.755, supp: 0.037, lift: 1.091, conv: 1.256)
# {Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.754, supp: 0.079, lift: 1.090, conv: 1.253)
# {Clear Invoice, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.759, supp: 0.044, lift: 1.097, conv: 1.278)
# {Clear Invoice, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.746, supp: 0.044, lift: 1.079, conv: 1.214)
# {Create Purchase Order Item, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.726, supp: 0.017, lift: 1.049, conv: 1.124)
# {Create Purchase Order Item, Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.721, supp: 0.041, lift: 1.041, conv: 1.102)
# {Create Purchase Order Item, Record Goods Receipt, Record Invoice Receipt, Remove Payment Block} -> {Vendor creates invoice} (conf: 0.702, supp: 0.041, lift: 1.140, conv: 1.290)
# {Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.716, supp: 0.023, lift: 1.035, conv: 1.084)
# {Create Purchase Order Item, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.723, supp: 0.018, lift: 1.045, conv: 1.113)
# {Record Goods Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.748, supp: 0.039, lift: 1.080, conv: 1.220)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.780, supp: 0.019, lift: 1.126, conv: 1.397)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.786, supp: 0.022, lift: 1.135, conv: 1.438)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.782, supp: 0.021, lift: 1.130, conv: 1.414)
# {Cancel Invoice Receipt, Clear Invoice, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.780, supp: 0.022, lift: 1.127, conv: 1.400)
# {Cancel Invoice Receipt, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.774, supp: 0.018, lift: 1.118, conv: 1.361)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.725, supp: 0.019, lift: 1.047, conv: 1.119)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.733, supp: 0.011, lift: 1.060, conv: 1.155)
# {Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.754, supp: 0.022, lift: 1.090, conv: 1.253)
# {Create Purchase Order Item, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.730, supp: 0.011, lift: 1.054, conv: 1.139)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.778, supp: 0.011, lift: 1.124, conv: 1.385)
# Association Rules for Transactions WITHOUT 'Remove Payment Block
#
# Frequent Itemsets (Without):
# 1: {('Record Invoice Receipt',): 118447, ('Clear Invoice',): 90354, ('Create Purchase Order Item',): 63639, ('Record Goods Receipt',): 136587, ('Vendor creates invoice',): 130990, ('Receive Order Confirmation',): 8400, ('Create Purchase Requisition Item',): 6871, ('Delete Purchase Order Item',): 2439, ('Change Quantity',): 54066, ('Change Price',): 33580, ('Vendor creates debit memo',): 37315, ('Cancel Invoice Receipt',): 30909, ('Record Service Entry Sheet',): 47649, ('Change Approval for Purchase Order',): 16052, ('SRM: Awaiting Approval',): 29638, ('SRM: Change was Transmitted',): 25721, ('SRM: Document Completed',): 31064, ('SRM: In Transfer to Execution Syst.',): 37393, ('SRM: Ordered',): 35593, ('SRM: Complete',): 27436, ('SRM: Created',): 24104, ('Change Delivery Indicator',): 21386, ('Cancel Goods Receipt',): 12622, ('Reactivate Purchase Order Item',): 3088, ('Release Purchase Order',): 11342, ('SRM: Deleted',): 13762}
# 2: {('Cancel Goods Receipt', 'Change Quantity'): 2624, ('Cancel Goods Receipt', 'Clear Invoice'): 4061, ('Cancel Goods Receipt', 'Create Purchase Order Item'): 2817, ('Cancel Goods Receipt', 'Record Goods Receipt'): 10071, ('Cancel Goods Receipt', 'Record Invoice Receipt'): 5318, ('Cancel Goods Receipt', 'Record Service Entry Sheet'): 4728, ('Cancel Goods Receipt', 'Vendor creates invoice'): 5311, ('Cancel Invoice Receipt', 'Change Delivery Indicator'): 2699, ('Cancel Invoice Receipt', 'Change Price'): 4587, ('Cancel Invoice Receipt', 'Change Quantity'): 5444, ('Cancel Invoice Receipt', 'Clear Invoice'): 21675, ('Cancel Invoice Receipt', 'Create Purchase Order Item'): 8914, ('Cancel Invoice Receipt', 'Record Goods Receipt'): 17652, ('Cancel Invoice Receipt', 'Record Invoice Receipt'): 24101, ('Cancel Invoice Receipt', 'Vendor creates debit memo'): 16329, ('Cancel Invoice Receipt', 'Vendor creates invoice'): 18350, ('Change Approval for Purchase Order', 'Change Price'): 7496, ('Change Approval for Purchase Order', 'Change Quantity'): 7039, ('Change Approval for Purchase Order', 'Clear Invoice'): 3579, ('Change Approval for Purchase Order', 'Create Purchase Order Item'): 3210, ('Change Approval for Purchase Order', 'Record Goods Receipt'): 7653, ('Change Approval for Purchase Order', 'Record Invoice Receipt'): 6248, ('Change Approval for Purchase Order', 'Release Purchase Order'): 9372, ('Change Approval for Purchase Order', 'Vendor creates invoice'): 7206, ('Change Delivery Indicator', 'Change Price'): 2365, ('Change Delivery Indicator', 'Change Quantity'): 12492, ('Change Delivery Indicator', 'Clear Invoice'): 8130, ('Change Delivery Indicator', 'Create Purchase Order Item'): 5631, ('Change Delivery Indicator', 'Record Goods Receipt'): 15329, ('Change Delivery Indicator', 'Record Invoice Receipt'): 12991, ('Change Delivery Indicator', 'Vendor creates debit memo'): 2781, ('Change Delivery Indicator', 'Vendor creates invoice'): 13689, ('Change Price', 'Change Quantity'): 11511, ('Change Price', 'Clear Invoice'): 12516, ('Change Price', 'Create Purchase Order Item'): 8367, ('Change Price', 'Record Goods Receipt'): 17823, ('Change Price', 'Record Invoice Receipt'): 15452, ('Change Price', 'Record Service Entry Sheet'): 2847, ('Change Price', 'Release Purchase Order'): 5870, ('Change Price', 'SRM: Awaiting Approval'): 2996, ('Change Price', 'SRM: Complete'): 2652, ('Change Price', 'SRM: Deleted'): 3543, ('Change Price', 'SRM: Document Completed'): 3222, ('Change Price', 'SRM: In Transfer to Execution Syst.'): 3697, ('Change Price', 'SRM: Ordered'): 3491, ('Change Price', 'Vendor creates debit memo'): 5319, ('Change Price', 'Vendor creates invoice'): 16626, ('Change Quantity', 'Clear Invoice'): 19084, ('Change Quantity', 'Create Purchase Order Item'): 14151, ('Change Quantity', 'Record Goods Receipt'): 38623, ('Change Quantity', 'Record Invoice Receipt'): 31159, ('Change Quantity', 'Release Purchase Order'): 5085, ('Change Quantity', 'Vendor creates debit memo'): 6454, ('Change Quantity', 'Vendor creates invoice'): 35833, ('Clear Invoice', 'Create Purchase Order Item'): 22343, ('Clear Invoice', 'Create Purchase Requisition Item'): 3438, ('Clear Invoice', 'Receive Order Confirmation'): 4044, ('Clear Invoice', 'Record Goods Receipt'): 58554, ('Clear Invoice', 'Record Invoice Receipt'): 64114, ('Clear Invoice', 'Record Service Entry Sheet'): 19616, ('Clear Invoice', 'SRM: Awaiting Approval'): 4938, ('Clear Invoice', 'SRM: Change was Transmitted'): 4869, ('Clear Invoice', 'SRM: Complete'): 4135, ('Clear Invoice', 'SRM: Created'): 3714, ('Clear Invoice', 'SRM: Deleted'): 3413, ('Clear Invoice', 'SRM: Document Completed'): 5494, ('Clear Invoice', 'SRM: In Transfer to Execution Syst.'): 7078, ('Clear Invoice', 'SRM: Ordered'): 7306, ('Clear Invoice', 'Vendor creates debit memo'): 21801, ('Clear Invoice', 'Vendor creates invoice'): 57532, ('Create Purchase Order Item', 'Create Purchase Requisition Item'): 3436, ('Create Purchase Order Item' ...
# ...
# 6: {('Cancel Invoice Receipt', 'Clear Invoice', 'Record Goods Receipt', 'Record Invoice Receipt', 'Vendor creates debit memo', 'Vendor creates invoice'): 3286}
#
# Association Rules (Without):
# {Cancel Goods Receipt} -> {Record Goods Receipt} (conf: 0.798, supp: 0.046, lift: 1.282, conv: 1.868)
# {Cancel Invoice Receipt} -> {Clear Invoice} (conf: 0.701, supp: 0.099, lift: 1.703, conv: 1.969)
# {Cancel Invoice Receipt} -> {Record Invoice Receipt} (conf: 0.780, supp: 0.110, lift: 1.444, conv: 2.089)
# {Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.826, supp: 0.043, lift: 11.294, conv: 5.336)
# {Change Delivery Indicator} -> {Record Goods Receipt} (conf: 0.717, supp: 0.070, lift: 1.151, conv: 1.333)
# {Change Quantity} -> {Record Goods Receipt} (conf: 0.714, supp: 0.176, lift: 1.147, conv: 1.321)
# {Clear Invoice} -> {Record Invoice Receipt} (conf: 0.710, supp: 0.292, lift: 1.314, conv: 1.584)
# {Record Service Entry Sheet} -> {Record Goods Receipt} (conf: 0.712, supp: 0.155, lift: 1.144, conv: 1.310)
# {Cancel Goods Receipt, Clear Invoice} -> {Record Goods Receipt} (conf: 0.712, supp: 0.013, lift: 1.144, conv: 1.311)
# {Cancel Goods Receipt, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.766, supp: 0.019, lift: 1.231, conv: 1.615)
# {Cancel Goods Receipt, Record Service Entry Sheet} -> {Record Goods Receipt} (conf: 0.870, supp: 0.019, lift: 1.397, conv: 2.897)
# {Cancel Goods Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.772, supp: 0.019, lift: 1.240, conv: 1.654)
# {Cancel Invoice Receipt, Change Price} -> {Record Invoice Receipt} (conf: 0.723, supp: 0.015, lift: 1.339, conv: 1.659)
# {Cancel Invoice Receipt, Change Quantity} -> {Record Invoice Receipt} (conf: 0.717, supp: 0.018, lift: 1.328, conv: 1.624)
# {Cancel Invoice Receipt, Record Invoice Receipt} -> {Clear Invoice} (conf: 0.722, supp: 0.079, lift: 1.753, conv: 2.115)
# {Cancel Invoice Receipt, Clear Invoice} -> {Record Invoice Receipt} (conf: 0.803, supp: 0.079, lift: 1.487, conv: 2.331)
# {Cancel Invoice Receipt, Create Purchase Order Item} -> {Record Invoice Receipt} (conf: 0.735, supp: 0.030, lift: 1.361, conv: 1.735)
# {Cancel Invoice Receipt, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.779, supp: 0.063, lift: 1.443, conv: 2.082)
# {Cancel Invoice Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.775, supp: 0.058, lift: 1.436, conv: 2.047)
# {Cancel Invoice Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.780, supp: 0.065, lift: 1.445, conv: 2.092)
# {Change Price, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.822, supp: 0.022, lift: 11.230, conv: 5.196)
# {Change Quantity, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.774, supp: 0.018, lift: 10.580, conv: 4.102)
# {Record Goods Receipt, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.780, supp: 0.017, lift: 10.657, conv: 4.207)
# {Record Invoice Receipt, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.826, supp: 0.013, lift: 11.293, conv: 5.334)
# {Release Purchase Order, Vendor creates invoice} -> {Change Approval for Purchase Order} (conf: 0.793, supp: 0.016, lift: 10.834, conv: 4.470)
# {Change Delivery Indicator, Change Quantity} -> {Record Goods Receipt} (conf: 0.755, supp: 0.043, lift: 1.213, conv: 1.542)
# {Change Delivery Indicator, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.719, supp: 0.043, lift: 1.155, conv: 1.343)
# {Change Delivery Indicator, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.744, supp: 0.046, lift: 1.195, conv: 1.473)
# {Change Quantity, Create Purchase Order Item} -> {Record Goods Receipt} (conf: 0.702, supp: 0.045, lift: 1.128, conv: 1.267)
# {Change Quantity, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.731, supp: 0.104, lift: 1.175, conv: 1.405)
# {Change Quantity, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.741, supp: 0.121, lift: 1.191, conv: 1.460)
# {Clear Invoice, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.722, supp: 0.193, lift: 1.337, conv: 1.655)
# {Clear Invoice, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.765, supp: 0.076, lift: 1.417, conv: 1.960)
# {Clear Invoice, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.723, supp: 0.190, lift: 1.339, conv: 1.660)
# {Receive Order Confirmation, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.701, supp: 0.018, lift: 1.126, conv: 1.261)
# {Receive Order Confirmation, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.717, supp: 0.018, lift: 1.152, conv: 1.333)
# {Record Invoice Receipt, Record Service Entry Sheet} -> {Record Goods Receipt} (conf: 0.706, supp: 0.077, lift: 1.134, conv: 1.284)
# {Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.712, supp: 0.249, lift: 1.143, conv: 1.309)
# {Record Service Entry Sheet, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.705, supp: 0.085, lift: 1.132, conv: 1.280)
# {Cancel Invoice Receipt, Change Quantity, Clear Invoice} -> {Record Invoice Receipt} (conf: 0.736, supp: 0.011, lift: 1.362, conv: 1.740)
# {Cancel Invoice Receipt, Change Quantity, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.713, supp: 0.011, lift: 1.321, conv: 1.605)
# {Cancel Invoice Receipt, Change Quantity, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.714, supp: 0.010, lift: 1.323, conv: 1.609)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item} -> {Record Invoice Receipt} (conf: 0.761, supp: 0.019, lift: 1.410, conv: 1.928)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.798, supp: 0.044, lift: 1.479, conv: 2.282)
# {Cancel Invoice Receipt, Record Invoice Receipt, Vendor creates debit memo} -> {Clear Invoice} (conf: 0.707, supp: 0.041, lift: 1.718, conv: 2.010)
# {Cancel Invoice Receipt, Clear Invoice, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.795, supp: 0.041, lift: 1.472, conv: 2.244)
# {Cancel Invoice Receipt, Record Invoice Receipt, Vendor creates invoice} -> {Clear Invoice} (conf: 0.709, supp: 0.046, lift: 1.722, conv: 2.021)
# {Cancel Invoice Receipt, Clear Invoice, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.798, supp: 0.046, lift: 1.478, conv: 2.276)
# {Cancel Invoice Receipt, Create Purchase Order Item, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.745, supp: 0.018, lift: 1.380, conv: 1.803)
# {Cancel Invoice Receipt, Create Purchase Order Item, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.734, supp: 0.017, lift: 1.360, conv: 1.730)
# {Cancel Invoice Receipt, Create Purchase Order Item, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.742, supp: 0.019, lift: 1.374, conv: 1.783)
# {Cancel Invoice Receipt, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.776, supp: 0.034, lift: 1.437, conv: 2.052)
# {Cancel Invoice Receipt, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.778, supp: 0.039, lift: 1.441, conv: 2.074)
# {Cancel Invoice Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.775, supp: 0.037, lift: 1.435, conv: 2.044)
# {Change Delivery Indicator, Change Quantity, Clear Invoice} -> {Record Goods Receipt} (conf: 0.700, supp: 0.012, lift: 1.125, conv: 1.260)
# {Change Delivery Indicator, Change Quantity, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.750, supp: 0.024, lift: 1.204, conv: 1.508)
# {Change Delivery Indicator, Change Quantity, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.764, supp: 0.029, lift: 1.227, conv: 1.599)
# {Change Delivery Indicator, Create Purchase Order Item, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.702, supp: 0.010, lift: 1.128, conv: 1.267)
# {Change Delivery Indicator, Create Purchase Order Item, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.717, supp: 0.012, lift: 1.151, conv: 1.332)
# {Change Delivery Indicator, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.737, supp: 0.028, lift: 1.184, conv: 1.434)
# {Change Price, Clear Invoice, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.720, supp: 0.011, lift: 1.333, conv: 1.641)
# {Change Quantity, Clear Invoice, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.706, supp: 0.041, lift: 1.134, conv: 1.284)
# {Change Quantity, Clear Invoice, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.721, supp: 0.012, lift: 1.335, conv: 1.648)
# {Change Quantity, Clear Invoice, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.700, supp: 0.040, lift: 1.297, conv: 1.536)
# {Change Quantity, Create Purchase Order Item, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.709, supp: 0.026, lift: 1.138, conv: 1.296)
# {Change Quantity, Create Purchase Order Item, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.723, supp: 0.031, lift: 1.162, conv: 1.365)
# {Change Quantity, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.749, supp: 0.074, lift: 1.203, conv: 1.504)
# {Change Quantity, Record Goods Receipt, Record Invoice Receipt} -> {Vendor creates invoice} (conf: 0.712, supp: 0.074, lift: 1.193, conv: 1.400)
# {Clear Invoice, Create Purchase Order Item, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.728, supp: 0.022, lift: 1.349, conv: 1.694)
# {Clear Invoice, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.768, supp: 0.046, lift: 1.422, conv: 1.983)
# {Clear Invoice, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.735, supp: 0.131, lift: 1.361, conv: 1.735)
# {Clear Invoice, Record Service Entry Sheet, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.706, supp: 0.039, lift: 1.134, conv: 1.284)
# {Clear Invoice, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.764, supp: 0.050, lift: 1.416, conv: 1.952)
# {Create Purchase Order Item, Record Goods Receipt, Record Invoice Receipt} -> {Vendor creates invoice} (conf: 0.709, supp: 0.068, lift: 1.187, conv: 1.384)
# {Receive Order Confirmation, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.731, supp: 0.013, lift: 1.175, conv: 1.406)
# {Receive Order Confirmation, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.708, supp: 0.013, lift: 1.311, conv: 1.575)
# {Receive Order Confirmation, Record Goods Receipt, Record Invoice Receipt} -> {Vendor creates invoice} (conf: 0.711, supp: 0.013, lift: 1.191, conv: 1.395)
# {Record Invoice Receipt, Record Service Entry Sheet, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.713, supp: 0.047, lift: 1.145, conv: 1.313)
# {Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.706, supp: 0.048, lift: 1.308, conv: 1.566)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.771, supp: 0.012, lift: 1.427, conv: 2.006)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.760, supp: 0.011, lift: 1.408, conv: 1.918)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.766, supp: 0.012, lift: 1.419, conv: 1.965)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.794, supp: 0.023, lift: 1.471, conv: 2.235)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.795, supp: 0.027, lift: 1.473, conv: 2.250)
# {Cancel Invoice Receipt, Record Invoice Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Clear Invoice} (conf: 0.700, supp: 0.026, lift: 1.700, conv: 1.961)
# {Cancel Invoice Receipt, Clear Invoice, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.792, supp: 0.026, lift: 1.466, conv: 2.208)
# {Cancel Invoice Receipt, Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.743, supp: 0.011, lift: 1.376, conv: 1.788)
# {Cancel Invoice Receipt, Create Purchase Order Item, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.746, supp: 0.012, lift: 1.381, conv: 1.809)
# {Cancel Invoice Receipt, Create Purchase Order Item, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.739, supp: 0.011, lift: 1.369, conv: 1.762)
# {Cancel Invoice Receipt, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.775, supp: 0.022, lift: 1.435, conv: 2.043)
# {Change Delivery Indicator, Change Quantity, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.754, supp: 0.017, lift: 1.212, conv: 1.537)
# {Change Quantity, Clear Invoice, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.709, supp: 0.029, lift: 1.139, conv: 1.298)
# {Change Quantity, Clear Invoice, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.704, supp: 0.029, lift: 1.303, conv: 1.552)
# {Change Quantity, Create Purchase Order Item, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.723, supp: 0.018, lift: 1.162, conv: 1.364)
# {Change Quantity, Create Purchase Order Item, Record Goods Receipt, Record Invoice Receipt} -> {Vendor creates invoice} (conf: 0.711, supp: 0.018, lift: 1.191, conv: 1.396)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.738, supp: 0.013, lift: 1.368, conv: 1.760)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Record Invoice Receipt} -> {Vendor creates invoice} (conf: 0.706, supp: 0.032, lift: 1.182, conv: 1.369)
# {Clear Invoice, Create Purchase Order Item, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.732, supp: 0.014, lift: 1.355, conv: 1.714)
# {Clear Invoice, Record Invoice Receipt, Record Service Entry Sheet, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.708, supp: 0.028, lift: 1.138, conv: 1.293)
# {Clear Invoice, Record Goods Receipt, Record Service Entry Sheet, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.702, supp: 0.028, lift: 1.300, conv: 1.543)
# {Clear Invoice, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.766, supp: 0.030, lift: 1.419, conv: 1.967)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.791, supp: 0.015, lift: 1.465, conv: 2.200)

# %% [markdown]
# comparisson

# %%
rules_with_set = set(rules_with)
rules_without_set = set(rules_without)

intersection_rules = rules_with_set & rules_without_set
difference_with = rules_with_set - rules_without_set
difference_without = rules_without_set - rules_with_set

print("\nIntersection of Rules:")
for rule in intersection_rules:
    print(rule)

print("\nRules in 'With Remove' but not in 'Without Remove':")
for rule in difference_with:
    print(rule)

print("\nRules in 'Without Remove' but not in 'With Remove':")
for rule in difference_without:
    print(rule)

# with open('intersection_rules.txt', 'w') as f:
#     f.write("Intersection of Rules:\n")
#     for rule in intersection_rules:
#         f.write(str(rule) + '\n')

# with open('difference_with_rules.txt', 'w') as f:
#     f.write("Rules in 'With Remove' but not in 'Without Remove':\n")
#     for rule in difference_with:
#         f.write(str(rule) + '\n')

# with open('difference_without_rules.txt', 'w') as f:
#     f.write("Rules in 'Without Remove' but not in 'With Remove':\n")
#     for rule in difference_without:
#         f.write(str(rule) + '\n')
# Out:
# Intersection of Rules:
# {Cancel Invoice Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.780, supp: 0.065, lift: 1.445, conv: 2.092)
# {Clear Invoice, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.735, supp: 0.131, lift: 1.361, conv: 1.735)
# {Clear Invoice, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.766, supp: 0.030, lift: 1.419, conv: 1.967)
# {Clear Invoice, Create Purchase Order Item, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.728, supp: 0.022, lift: 1.349, conv: 1.694)
# {Clear Invoice, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.764, supp: 0.050, lift: 1.416, conv: 1.952)
# {Cancel Invoice Receipt, Change Quantity, Clear Invoice} -> {Record Invoice Receipt} (conf: 0.736, supp: 0.011, lift: 1.362, conv: 1.740)
# {Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.826, supp: 0.043, lift: 11.294, conv: 5.336)
# {Cancel Invoice Receipt, Create Purchase Order Item} -> {Record Invoice Receipt} (conf: 0.735, supp: 0.030, lift: 1.361, conv: 1.735)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.771, supp: 0.012, lift: 1.427, conv: 2.006)
# {Clear Invoice, Create Purchase Order Item, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.732, supp: 0.014, lift: 1.355, conv: 1.714)
# {Record Goods Receipt, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.780, supp: 0.017, lift: 10.657, conv: 4.207)
# {Record Invoice Receipt, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.826, supp: 0.013, lift: 11.293, conv: 5.334)
# {Clear Invoice, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.722, supp: 0.193, lift: 1.337, conv: 1.655)
# {Cancel Invoice Receipt, Clear Invoice} -> {Record Invoice Receipt} (conf: 0.803, supp: 0.079, lift: 1.487, conv: 2.331)
# {Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.706, supp: 0.048, lift: 1.308, conv: 1.566)
# {Cancel Invoice Receipt, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.775, supp: 0.022, lift: 1.435, conv: 2.043)
# {Cancel Invoice Receipt, Create Purchase Order Item, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.742, supp: 0.019, lift: 1.374, conv: 1.783)
# {Cancel Invoice Receipt, Create Purchase Order Item, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.734, supp: 0.017, lift: 1.360, conv: 1.730)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.798, supp: 0.044, lift: 1.479, conv: 2.282)
# {Change Price, Clear Invoice, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.720, supp: 0.011, lift: 1.333, conv: 1.641)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.795, supp: 0.027, lift: 1.473, conv: 2.250)
# {Cancel Goods Receipt, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.766, supp: 0.019, lift: 1.231, conv: 1.615)
# {Cancel Invoice Receipt, Change Price} -> {Record Invoice Receipt} (conf: 0.723, supp: 0.015, lift: 1.339, conv: 1.659)
# {Change Quantity, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.774, supp: 0.018, lift: 10.580, conv: 4.102)
# {Cancel Invoice Receipt, Clear Invoice, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.798, supp: 0.046, lift: 1.478, conv: 2.276)
# {Cancel Invoice Receipt, Clear Invoice, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.795, supp: 0.041, lift: 1.472, conv: 2.244)
# {Cancel Invoice Receipt, Create Purchase Order Item, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.745, supp: 0.018, lift: 1.380, conv: 1.803)
# {Cancel Invoice Receipt, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.778, supp: 0.039, lift: 1.441, conv: 2.074)
# {Cancel Invoice Receipt, Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.743, supp: 0.011, lift: 1.376, conv: 1.788)
# {Receive Order Confirmation, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.708, supp: 0.013, lift: 1.311, conv: 1.575)
# {Cancel Invoice Receipt, Clear Invoice, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.792, supp: 0.026, lift: 1.466, conv: 2.208)
# {Release Purchase Order, Vendor creates invoice} -> {Change Approval for Purchase Order} (conf: 0.793, supp: 0.016, lift: 10.834, conv: 4.470)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.738, supp: 0.013, lift: 1.368, conv: 1.760)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.760, supp: 0.011, lift: 1.408, conv: 1.918)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.766, supp: 0.012, lift: 1.419, conv: 1.965)
# {Cancel Invoice Receipt, Change Quantity, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.714, supp: 0.010, lift: 1.323, conv: 1.609)
# {Clear Invoice, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.765, supp: 0.076, lift: 1.417, conv: 1.960)
# {Cancel Invoice Receipt, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.776, supp: 0.034, lift: 1.437, conv: 2.052)
# {Cancel Goods Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.772, supp: 0.019, lift: 1.240, conv: 1.654)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.791, supp: 0.015, lift: 1.465, conv: 2.200)
# {Cancel Invoice Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.775, supp: 0.058, lift: 1.436, conv: 2.047)
# {Clear Invoice, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.768, supp: 0.046, lift: 1.422, conv: 1.983)
# {Cancel Invoice Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.775, supp: 0.037, lift: 1.435, conv: 2.044)
# {Cancel Goods Receipt} -> {Record Goods Receipt} (conf: 0.798, supp: 0.046, lift: 1.282, conv: 1.868)
# {Cancel Invoice Receipt, Change Quantity, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.713, supp: 0.011, lift: 1.321, conv: 1.605)
# {Cancel Invoice Receipt} -> {Record Invoice Receipt} (conf: 0.780, supp: 0.110, lift: 1.444, conv: 2.089)
# {Cancel Invoice Receipt, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.779, supp: 0.063, lift: 1.443, conv: 2.082)
# {Create Purchase Order Item, Record Goods Receipt, Record Invoice Receipt} -> {Vendor creates invoice} (conf: 0.709, supp: 0.068, lift: 1.187, conv: 1.384)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item} -> {Record Invoice Receipt} (conf: 0.761, supp: 0.019, lift: 1.410, conv: 1.928)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.794, supp: 0.023, lift: 1.471, conv: 2.235)
# {Change Quantity, Clear Invoice, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.704, supp: 0.029, lift: 1.303, conv: 1.552)
# {Cancel Invoice Receipt, Create Purchase Order Item, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.739, supp: 0.011, lift: 1.369, conv: 1.762)
# {Cancel Invoice Receipt, Create Purchase Order Item, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.746, supp: 0.012, lift: 1.381, conv: 1.809)
# {Clear Invoice} -> {Record Invoice Receipt} (conf: 0.710, supp: 0.292, lift: 1.314, conv: 1.584)
# {Cancel Invoice Receipt, Change Quantity} -> {Record Invoice Receipt} (conf: 0.717, supp: 0.018, lift: 1.328, conv: 1.624)
# {Change Price, Release Purchase Order} -> {Change Approval for Purchase Order} (conf: 0.822, supp: 0.022, lift: 11.230, conv: 5.196)
# {Clear Invoice, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.723, supp: 0.190, lift: 1.339, conv: 1.660)
#
# Rules in 'With Remove' but not in 'Without Remove':
# {Cancel Goods Receipt, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.741, supp: 0.011, lift: 1.214, conv: 1.505)
# {Cancel Invoice Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.777, supp: 0.059, lift: 1.122, conv: 1.380)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.714, supp: 0.050, lift: 1.032, conv: 1.078)
# {Clear Invoice, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.750, supp: 0.131, lift: 1.084, conv: 1.234)
# {Cancel Invoice Receipt, Change Price, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.756, supp: 0.011, lift: 1.092, conv: 1.260)
# {Receive Order Confirmation, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.711, supp: 0.011, lift: 1.027, conv: 1.064)
# {Cancel Invoice Receipt, Create Purchase Order Item, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.749, supp: 0.013, lift: 1.083, conv: 1.228)
# {Create Purchase Order Item, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.716, supp: 0.028, lift: 1.035, conv: 1.084)
# {Cancel Goods Receipt, Remove Payment Block} -> {Record Goods Receipt} (conf: 0.726, supp: 0.016, lift: 1.190, conv: 1.423)
# {Record Goods Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.748, supp: 0.062, lift: 1.081, conv: 1.223)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.717, supp: 0.028, lift: 1.036, conv: 1.089)
# {Clear Invoice, Create Purchase Order Item} -> {Record Invoice Receipt} (conf: 0.702, supp: 0.076, lift: 1.015, conv: 1.034)
# {Cancel Invoice Receipt, Clear Invoice, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.801, supp: 0.088, lift: 1.157, conv: 1.545)
# {Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.736, supp: 0.224, lift: 1.064, conv: 1.167)
# {Cancel Invoice Receipt, Change Quantity, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.703, supp: 0.016, lift: 1.015, conv: 1.036)
# {Cancel Invoice Receipt, Change Price, Clear Invoice} -> {Record Invoice Receipt} (conf: 0.767, supp: 0.013, lift: 1.108, conv: 1.322)
# {Cancel Invoice Receipt, Clear Invoice, Create Purchase Order Item, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.752, supp: 0.012, lift: 1.086, conv: 1.239)
# {Create Purchase Order Item, Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.721, supp: 0.041, lift: 1.041, conv: 1.102)
# {Create Purchase Order Item, Record Goods Receipt, Record Invoice Receipt, Remove Payment Block} -> {Vendor creates invoice} (conf: 0.702, supp: 0.041, lift: 1.140, conv: 1.290)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.733, supp: 0.011, lift: 1.060, conv: 1.155)
# {Cancel Invoice Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.777, supp: 0.035, lift: 1.123, conv: 1.382)
# {Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.755, supp: 0.037, lift: 1.091, conv: 1.256)
# {Clear Invoice, Create Purchase Order Item, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.703, supp: 0.042, lift: 1.016, conv: 1.036)
# {Release Purchase Order, Remove Payment Block} -> {Change Approval for Purchase Order} (conf: 0.762, supp: 0.012, lift: 12.716, conv: 3.951)
# {Cancel Invoice Receipt, Change Quantity, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.707, supp: 0.014, lift: 1.021, conv: 1.050)
# {Cancel Invoice Receipt, Create Purchase Order Item, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.763, supp: 0.013, lift: 1.102, conv: 1.297)
# {Cancel Invoice Receipt, Change Price, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.760, supp: 0.011, lift: 1.098, conv: 1.282)
# {Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.736, supp: 0.221, lift: 1.064, conv: 1.167)
# {Cancel Invoice Receipt, Create Purchase Order Item, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.750, supp: 0.022, lift: 1.083, conv: 1.231)
# {Cancel Invoice Receipt, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.775, supp: 0.030, lift: 1.120, conv: 1.371)
# {Receive Order Confirmation, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.707, supp: 0.017, lift: 1.021, conv: 1.050)
# {Clear Invoice, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.751, supp: 0.222, lift: 1.084, conv: 1.234)
# {Cancel Invoice Receipt, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.785, supp: 0.061, lift: 1.134, conv: 1.430)
# {Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.716, supp: 0.023, lift: 1.035, conv: 1.084)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.725, supp: 0.019, lift: 1.047, conv: 1.119)
# {Cancel Invoice Receipt, Clear Invoice, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.790, supp: 0.043, lift: 1.141, conv: 1.464)
# {Clear Invoice, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.745, supp: 0.074, lift: 1.077, conv: 1.210)
# {Cancel Invoice Receipt, Change Price, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.758, supp: 0.011, lift: 1.095, conv: 1.271)
# {Create Purchase Order Item, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.711, supp: 0.060, lift: 1.028, conv: 1.067)
# {Cancel Invoice Receipt, Create Purchase Order Item, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.756, supp: 0.014, lift: 1.093, conv: 1.264)
# {Record Goods Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.748, supp: 0.039, lift: 1.080, conv: 1.220)
# {Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.740, supp: 0.140, lift: 1.070, conv: 1.186)
# {Cancel Invoice Receipt, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.774, supp: 0.018, lift: 1.118, conv: 1.361)
# {Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.721, supp: 0.287, lift: 1.042, conv: 1.104)
# {Clear Invoice, Record Service Entry Sheet} -> {Record Invoice Receipt} (conf: 0.734, supp: 0.017, lift: 1.061, conv: 1.158)
# {Cancel Invoice Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.794, supp: 0.126, lift: 1.147, conv: 1.492)
# {Clear Invoice, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.751, supp: 0.124, lift: 1.085, conv: 1.236)
# {Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.754, supp: 0.022, lift: 1.090, conv: 1.253)
# {Create Purchase Order Item, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.707, supp: 0.037, lift: 1.022, conv: 1.052)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.778, supp: 0.011, lift: 1.124, conv: 1.385)
# {Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.708, supp: 0.432, lift: 1.023, conv: 1.055)
# {Change Quantity, Clear Invoice, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.700, supp: 0.049, lift: 1.012, conv: 1.027)
# {Clear Invoice, Create Purchase Order Item, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.712, supp: 0.051, lift: 1.029, conv: 1.069)
# {Create Purchase Order Item, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.712, supp: 0.034, lift: 1.028, conv: 1.068)
# {Cancel Goods Receipt, Create Purchase Order Item} -> {Record Goods Receipt} (conf: 0.733, supp: 0.011, lift: 1.201, conv: 1.460)
# {Cancel Invoice Receipt, Clear Invoice, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.780, supp: 0.039, lift: 1.127, conv: 1.400)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.780, supp: 0.019, lift: 1.126, conv: 1.397)
# {Clear Invoice, Create Purchase Order Item, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.718, supp: 0.015, lift: 1.038, conv: 1.093)
# {Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.709, supp: 0.437, lift: 1.024, conv: 1.058)
# {Cancel Invoice Receipt, Change Price, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.766, supp: 0.012, lift: 1.106, conv: 1.314)
# {Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.742, supp: 0.124, lift: 1.072, conv: 1.193)
# {Create Purchase Order Item, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.712, supp: 0.058, lift: 1.028, conv: 1.068)
# {Record Subsequent Invoice} -> {Clear Invoice} (conf: 0.704, supp: 0.012, lift: 1.371, conv: 1.643)
# {Cancel Subsequent Invoice, Remove Payment Block, Vendor creates debit memo} -> {Clear Invoice} (conf: 0.714, supp: 0.011, lift: 1.390, conv: 1.700)
# {Clear Invoice, Record Goods Receipt, Record Service Entry Sheet} -> {Record Invoice Receipt} (conf: 0.718, supp: 0.010, lift: 1.037, conv: 1.091)
# {Cancel Subsequent Invoice, Remove Payment Block} -> {Clear Invoice} (conf: 0.716, supp: 0.019, lift: 1.394, conv: 1.712)
# {Receive Order Confirmation, Record Goods Receipt} -> {Record Invoice Receipt} (conf: 0.706, supp: 0.022, lift: 1.021, conv: 1.048)
# {Create Purchase Order Item, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.723, supp: 0.018, lift: 1.045, conv: 1.113)
# {Change Price, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.715, supp: 0.013, lift: 1.033, conv: 1.080)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.790, supp: 0.040, lift: 1.142, conv: 1.469)
# {Change Price, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.724, supp: 0.012, lift: 1.046, conv: 1.115)
# {Cancel Invoice Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.785, supp: 0.067, lift: 1.135, conv: 1.435)
# {Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.742, supp: 0.231, lift: 1.072, conv: 1.194)
# {Change Price, Record Goods Receipt, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.711, supp: 0.012, lift: 1.027, conv: 1.064)
# {Create Purchase Order Item, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.726, supp: 0.017, lift: 1.049, conv: 1.124)
# {Cancel Invoice Receipt, Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.786, supp: 0.022, lift: 1.135, conv: 1.438)
# {Clear Invoice, Create Purchase Order Item, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.713, supp: 0.028, lift: 1.030, conv: 1.073)
# {Clear Invoice, Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.754, supp: 0.079, lift: 1.090, conv: 1.253)
# {Cancel Invoice Receipt, Clear Invoice, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.780, supp: 0.022, lift: 1.127, conv: 1.400)
# {Clear Invoice, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.746, supp: 0.044, lift: 1.079, conv: 1.214)
# {Cancel Invoice Receipt, Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.781, supp: 0.036, lift: 1.129, conv: 1.409)
# {Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.733, supp: 0.372, lift: 1.059, conv: 1.153)
# {Change Price, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.715, supp: 0.024, lift: 1.032, conv: 1.079)
# {Record Goods Receipt, Remove Payment Block, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.746, supp: 0.148, lift: 1.078, conv: 1.211)
# {Remove Payment Block, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.744, supp: 0.117, lift: 1.075, conv: 1.203)
# {Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.745, supp: 0.072, lift: 1.077, conv: 1.209)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.721, supp: 0.034, lift: 1.042, conv: 1.104)
# {Create Purchase Order Item, Record Goods Receipt, Remove Payment Block, Vendor creates debit memo, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.730, supp: 0.011, lift: 1.054, conv: 1.139)
# {Receive Order Confirmation, Record Goods Receipt, Remove Payment Block} -> {Record Invoice Receipt} (conf: 0.721, supp: 0.011, lift: 1.042, conv: 1.105)
#
# Rules in 'Without Remove' but not in 'With Remove':
# {Change Delivery Indicator} -> {Record Goods Receipt} (conf: 0.717, supp: 0.070, lift: 1.151, conv: 1.333)
# {Record Service Entry Sheet, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.705, supp: 0.085, lift: 1.132, conv: 1.280)
# {Change Quantity, Create Purchase Order Item, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.709, supp: 0.026, lift: 1.138, conv: 1.296)
# {Cancel Goods Receipt, Clear Invoice} -> {Record Goods Receipt} (conf: 0.712, supp: 0.013, lift: 1.144, conv: 1.311)
# {Change Quantity, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.731, supp: 0.104, lift: 1.175, conv: 1.405)
# {Clear Invoice, Record Invoice Receipt, Record Service Entry Sheet, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.708, supp: 0.028, lift: 1.138, conv: 1.293)
# {Change Delivery Indicator, Change Quantity, Clear Invoice} -> {Record Goods Receipt} (conf: 0.700, supp: 0.012, lift: 1.125, conv: 1.260)
# {Change Delivery Indicator, Create Purchase Order Item, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.717, supp: 0.012, lift: 1.151, conv: 1.332)
# {Clear Invoice, Record Goods Receipt, Record Service Entry Sheet, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.702, supp: 0.028, lift: 1.300, conv: 1.543)
# {Record Invoice Receipt, Record Service Entry Sheet, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.713, supp: 0.047, lift: 1.145, conv: 1.313)
# {Change Quantity} -> {Record Goods Receipt} (conf: 0.714, supp: 0.176, lift: 1.147, conv: 1.321)
# {Change Delivery Indicator, Create Purchase Order Item, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.702, supp: 0.010, lift: 1.128, conv: 1.267)
# {Change Delivery Indicator, Change Quantity, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.754, supp: 0.017, lift: 1.212, conv: 1.537)
# {Change Quantity, Create Purchase Order Item, Record Goods Receipt, Record Invoice Receipt} -> {Vendor creates invoice} (conf: 0.711, supp: 0.018, lift: 1.191, conv: 1.396)
# {Change Quantity, Create Purchase Order Item, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.723, supp: 0.018, lift: 1.162, conv: 1.364)
# {Cancel Invoice Receipt, Record Invoice Receipt} -> {Clear Invoice} (conf: 0.722, supp: 0.079, lift: 1.753, conv: 2.115)
# {Record Invoice Receipt, Record Service Entry Sheet} -> {Record Goods Receipt} (conf: 0.706, supp: 0.077, lift: 1.134, conv: 1.284)
# {Change Quantity, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.749, supp: 0.074, lift: 1.203, conv: 1.504)
# {Cancel Invoice Receipt} -> {Clear Invoice} (conf: 0.701, supp: 0.099, lift: 1.703, conv: 1.969)
# {Change Quantity, Record Goods Receipt, Record Invoice Receipt} -> {Vendor creates invoice} (conf: 0.712, supp: 0.074, lift: 1.193, conv: 1.400)
# {Cancel Invoice Receipt, Record Invoice Receipt, Vendor creates debit memo} -> {Clear Invoice} (conf: 0.707, supp: 0.041, lift: 1.718, conv: 2.010)
# {Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.712, supp: 0.249, lift: 1.143, conv: 1.309)
# {Cancel Invoice Receipt, Record Invoice Receipt, Vendor creates invoice} -> {Clear Invoice} (conf: 0.709, supp: 0.046, lift: 1.722, conv: 2.021)
# {Change Delivery Indicator, Change Quantity, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.750, supp: 0.024, lift: 1.204, conv: 1.508)
# {Receive Order Confirmation, Record Goods Receipt, Record Invoice Receipt} -> {Vendor creates invoice} (conf: 0.711, supp: 0.013, lift: 1.191, conv: 1.395)
# {Receive Order Confirmation, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.731, supp: 0.013, lift: 1.175, conv: 1.406)
# {Change Delivery Indicator, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.744, supp: 0.046, lift: 1.195, conv: 1.473)
# {Cancel Invoice Receipt, Record Invoice Receipt, Vendor creates debit memo, Vendor creates invoice} -> {Clear Invoice} (conf: 0.700, supp: 0.026, lift: 1.700, conv: 1.961)
# {Clear Invoice, Record Service Entry Sheet, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.706, supp: 0.039, lift: 1.134, conv: 1.284)
# {Change Quantity, Create Purchase Order Item, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.723, supp: 0.031, lift: 1.162, conv: 1.365)
# {Record Service Entry Sheet} -> {Record Goods Receipt} (conf: 0.712, supp: 0.155, lift: 1.144, conv: 1.310)
# {Change Quantity, Clear Invoice, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.706, supp: 0.041, lift: 1.134, conv: 1.284)
# {Change Quantity, Create Purchase Order Item} -> {Record Goods Receipt} (conf: 0.702, supp: 0.045, lift: 1.128, conv: 1.267)
# {Change Delivery Indicator, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.719, supp: 0.043, lift: 1.155, conv: 1.343)
# {Change Delivery Indicator, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.737, supp: 0.028, lift: 1.184, conv: 1.434)
# {Change Quantity, Clear Invoice, Record Invoice Receipt, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.709, supp: 0.029, lift: 1.139, conv: 1.298)
# {Receive Order Confirmation, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.717, supp: 0.018, lift: 1.152, conv: 1.333)
# {Change Delivery Indicator, Change Quantity} -> {Record Goods Receipt} (conf: 0.755, supp: 0.043, lift: 1.213, conv: 1.542)
# {Change Quantity, Clear Invoice, Vendor creates debit memo} -> {Record Invoice Receipt} (conf: 0.721, supp: 0.012, lift: 1.335, conv: 1.648)
# {Change Quantity, Clear Invoice, Vendor creates invoice} -> {Record Invoice Receipt} (conf: 0.700, supp: 0.040, lift: 1.297, conv: 1.536)
# {Receive Order Confirmation, Record Invoice Receipt} -> {Record Goods Receipt} (conf: 0.701, supp: 0.018, lift: 1.126, conv: 1.261)
# {Change Quantity, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.741, supp: 0.121, lift: 1.191, conv: 1.460)
# {Change Delivery Indicator, Change Quantity, Vendor creates invoice} -> {Record Goods Receipt} (conf: 0.764, supp: 0.029, lift: 1.227, conv: 1.599)
# {Cancel Goods Receipt, Record Service Entry Sheet} -> {Record Goods Receipt} (conf: 0.870, supp: 0.019, lift: 1.397, conv: 2.897)
# {Clear Invoice, Create Purchase Order Item, Record Goods Receipt, Record Invoice Receipt} -> {Vendor creates invoice} (conf: 0.706, supp: 0.032, lift: 1.182, conv: 1.369)
